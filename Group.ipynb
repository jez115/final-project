# %% [markdown]
# **Introduction**: Introduce the project, and your approach, talk about the process of how you came up with the metric and some alternatives you may have explored.
#
# To us, the best neighborhood would be safe, fun, and clean. To find which neighborhood best meets these qualities, we looked at crime activity, fire incidents, frequency of smart trash cans, and number of playgrounds in each of those neighborhoods because these are things that heavily impact quality of life of the families living there.
#
# **The Metric**: Describe your metric, and what features are you measuring. What datasets are you using?
#
# 1. Criminal Activity
#     1. Saint Clair
#     2. Ridgemont
#     3. Chartiers
# 2. Fire Incidents
#     1. Regent Square
#     2. Ridgemont
#     3. East Carnegie
# 3. Smart Trash
#     1. Shadyside
#     2. East Liberty
#     3. Squirrel Hill South
# 4. Playgrounds
#     1. Squirrel Hill South
#     2. Beechview
#     3. South Side Slopes
#
#
#
# **The Best Neighborhood**: Apply the metric from the previous section to determine the best neighborhood in Pittsburgh. Beyond just executing code, provide a narrative about why you think this is the best neighborhood. Incorporate a data visualization, perhaps to rank all of the neighborhoods or show a neighborhood’s best-ness over time. The key is to make a data driven argument.
#
# [JENNIFER WRITE HERE]
#
# **Conclusion**: Reflect on how the data-driven determination of “best neighborhood” is the same or different from your personal favorite neighborhood. Each member of the group should write their own response to this.
#
# <u>Emily's conclusion<u: _My favorite neighborhoods is Shadyside, which I love because of the amount of boba and matcha shops. Unfortunately, Shadyside is one of the neighborhoods with the greatest amount of crime and fire incidents, so I would not want to live there. I think it is better for just visiting._
