# %% [markdown]
# # Playground Dataset

# %% [markdown]
# We are measuring the number of playgrounds in each neighborhood and consider neighborhoods with **more** playgrounds to be "**better**." The data was last updated in 2021 because of a broken data feed.
#
# Here is the link to the dataset: https://data.wprdc.org/dataset/playgrounds/resource/47350364-44a8-4d15-b6e0-5f79ddff9367
#
# Below is a preview of the original data:

# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
playground = pd.read_csv('playground.csv')
playground.head(10)
# Out:
#    _id          id                      name  type maintenance_responsibility  \
# 0    1   731501774      Able Long Playground   NaN            Parks - Western
# 1    2  1461276747  Albert Graham Playground   NaN           Parks - Schenley
# 2    3  1860709784         Alpine Playground   NaN           Parks - Northern
# 3    4  1770671485          Alton Playground   NaN            Parks - Western
# 4    5    18942817          Ammon Playground   NaN           Parks - Schenley
# 5    6   230731204      Arlington Playground   NaN           Parks - Southern
# 6    7   420573029      Armstrong Playground   NaN           Parks - Southern
# 7    8   113170092        Arsenal Playground   NaN          Parks - Northeast
# 8    9  2089697067  August WIlson Playground   NaN           Parks - Schenley
# 9   10  2124405123     Banksville Playground   NaN            Parks - Western
#
#                       park       street  \
# 0           Able Long Park    COAST AVE
# ...

# %% [markdown]
# By organizing the neighborhoods in alphabetical order, we can see how many playgrounds correspond to the same neighborhood:

# %%
p2 = playground.sort_values(by = "neighborhood")
p2.head(10)
# Out:
#      _id          id                           name  type  \
# 103  104   569607016          Sue Murray Playground   NaN
# 26    27   740206795            Deer Pit Playground   NaN
# 79    80  2024492541          North Ave. Playground   NaN
# 119  120  1137558943  Martin Luther King Playground   NaN
# 46    47  1047459498           Grandview Playground   NaN
# 9     10  2124405123          Banksville Playground   NaN
# 4      5    18942817               Ammon Playground   NaN
# 0      1   731501774           Able Long Playground   NaN
# 3      4  1770671485               Alton Playground   NaN
# 85    86   698726686             Pauline Playground   NaN
#
#     maintenance_responsibility                                park  \
# 103           Parks - Northern                   Allegheny Commons
# 26            Parks - Northern                   Allegheny Commons
# 79            Parks - Northern                   Allegheny Commons
# ...

# %% [markdown]
# Below is condensed dataset of the neighborhoods and their playground count:

# %%
p2 = playground['neighborhood'].value_counts().sort_values(ascending = False)
p2.head(10)
# Out:
# neighborhood
# Squirrel Hill South    8
# Beechview              5
# South Side Slopes      5
# Highland Park          4
# Sheraden               4
# Beltzhoover            4
# Allegheny Center       4
# Crawford-Roberts       3
# Elliott                3
# South Oakland          3
# Name: count, dtype: int64

# %% [markdown]
# Finally, we can summarize the data visually with a bar chart.

# %%
p2.plot(kind = "bar", width = .4, figsize=(25,10), ylim=(0,8))
plt.ylabel("number of playgrounds")
plt.title("Playgrounds in Pittsburgh Neighborhoods", fontsize = 18)
plt.show()

# %% [markdown]
# From the bar chart, we can summarize:
# 1. Maximum: 8
# 2. Minimum: 1
# 3. **First best**: Squirrel Hill South
# 4. **Second best**: Beechview
# 5. **Third best**: South Side Slopes
